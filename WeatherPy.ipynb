# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from pprint import pprint
import datetime

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
coord = []
humidity = []
wind = []
clouds = []
temp = []
date = []
lat = []
speed = []
lon = []
now = datetime.datetime.now()

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)



# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 628

# %%
cities
# Out:
# ['illoqqortoormiut',
#  'aykhal',
#  'hermanus',
#  'boralday',
#  'cape town',
#  'ushuaia',
#  'dwarka',
#  'otradnoye',
#  'port lincoln',
#  'jamestown',
#  'ibra',
#  'belushya guba',
#  'mar del plata',
#  'cidreira',
#  'nizhneyansk',
#  'busselton',
#  'barrow',
#  'porto velho',
#  'bluff',
#  'yeniseysk',
#  'mataura',
#  'hilo',
#  'oyama',
#  'bredasdorp',
#  'lagoa',
#  'khatanga',
#  'georgetown',
#  'sorvag',
#  'fangshan',
#  'puerto ayora',
#  'new norfolk',
#  'luderitz',
#  'bambous virieux',
#  'ribeira grande',
#  'charters towers',
#  'amderma',
#  'padre bernardo',
#  'great falls',
#  'albany',
#  'rikitea',
#  'pangody',
#  'salinas',
#  'gigmoto',
#  'elat',
#  'magadan',
#  'dikson',
#  'arraial do cabo',
#  'tuktoyaktuk',
#  'westport',
#  'attawapiskat',
#  'natalio',
#  'lavrentiya',
#  'kodiak',
#  'saskylakh',
#  'alihe',
#  'kohima',
#  'mount isa',
#  'airai',
#  'nikolskoye',
#  'qaanaaq',
#  'butaritari',
#  'kaitangata',
#  'ranfurly',
#  'upernavik',
#  'san jose',
#  'tasiilaq',
#  'komsomolskiy',
#  'punta arenas',
#  'mayor pablo lagerenza',
#  'hay river',
#  'klaksvik',
#  'rungata',
#  'hue',
#  'pisco',
#  'carlagan',
#  'pevek',
#  'richard toll',
#  'matagami',
#  'taolanaro',
#  'tukrah',
#  'havoysund',
#  'port alfred',
#  'hoopstad',
#  'lebu',
#  'sept-iles',
#  'vaini',
#  'manuk mangkaw',
#  'chester',
#  'tarrafal',
#  'saint george',
#  'marcona',
#  'tuatapere',
#  'kosmynino',
#  'okha',
#  'pierre',
#  'ozark',
#  'mizdah',
#  'viedma',
#  'yumen',
#  'xilopolis',
#  'thompson',
#  'atuona',
#  'isla vista',
#  'makakilo city',
#  'iqaluit',
#  'loandjili',
#  'porto santo',
#  'hovd',
#  'korla',
#  'minas',
#  'torbay',
#  'san esteban',
#  'fuerte olimpo',
#  'loiza',
#  'ternate',
#  'ukiah',
#  'esperance',
#  'ambon',
#  'half moon bay',
#  'touros',
#  'namtsy',
#  'kupang',
#  'okhotsk',
#  'lorengau',
#  'roald',
#  'kuching',
#  'capinopolis',
#  'horsham',
#  'avarua',
#  'buraydah',
#  'biak',
#  'gazanjyk',
#  'ixtapa',
#  'faanui',
#  'moen',
#  'saleaula',
#  'dordrecht',
#  'longyearbyen',
#  'trincomalee',
#  'puerto leguizamo',
#  'port elizabeth',
#  'chokurdakh',
#  'ostrovnoy',
#  'bethel',
#  'cururupu',
#  'tidore',
#  'tingi',
#  'bud',
#  'castro',
#  'pangnirtung',
#  'altay',
#  'mahibadhoo',
#  'bathsheba',
#  'the pas',
#  'nalut',
#  'sing buri',
#  'hithadhoo',
#  'kruisfontein',
#  'bairiki',
#  'ionia',
#  'sechura',
#  'tual',
#  'kilindoni',
#  'havelock',
#  'warqla',
#  'hasaki',
#  'buala',
#  'albanel',
#  'avera',
#  'sampit',
#  'ferkessedougou',
#  'omboue',
#  'mon',
#  'katsuura',
#  'hobart',
#  'paita',
#  'antalaha',
#  'rio gallegos',
#  'clyde river',
#  'zhigansk',
#  'krasnyy yar',
#  'gluckstadt',
#  'nanortalik',
#  'sinnamary',
#  'katherine',
#  'severo-kurilsk',
#  'ngukurr',
#  'foumbot',
#  'diego de almagro',
#  'yellowknife',
#  'kapaa',
#  'sioux lookout',
#  'semenivka',
#  'port augusta',
#  'bilma',
#  'samusu',
#  'cayenne',
#  'vadso',
#  'mehamn',
#  'lake charles',
#  'tiksi',
#  'methoni',
#  'buin',
#  'sitka',
#  'vardo',
#  'grand gaube',
#  'chingola',
#  'svetlogorsk',
#  'mocambique',
#  'kuche',
#  'seoul',
#  'zemio',
#  'namatanai',
#  'flin flon',
#  'kihei',
#  'barentsburg',
#  'gushikawa',
#  'leningradskiy',
#  'nchelenge',
#  'te anau',
#  'cherskiy',
#  'nouadhibou',
#  'nouakchott',
#  'calvillo',
#  'saint-pierre',
#  'usevya',
#  'naguabo',
#  'mahebourg',
#  'vallenar',
#  'katsina',
#  'malinovoye ozero',
#  'gallup',
#  'dakar',
#  'dubenskiy',
#  'kasongo-lunda',
#  'economy',
#  'chuy',
#  'talnakh',
#  'virginia beach',
#  'narsaq',
#  'tazovskiy',
#  'kyzyl-suu',
#  'tlahualilo',
#  'salina cruz',
#  'tumannyy',
#  'sigli',
#  'ancud',
#  'rincon',
#  'havre-saint-pierre',
#  'omsukchan',
#  'denpasar',
#  'wajima',
#  'haines junction',
#  'maues',
#  'yulara',
#  'pacific grove',
#  'zlitan',
#  'mineiros',
#  'kuhdasht',
#  'lata',
#  'lukovetskiy',
#  'burnie',
#  'tsihombe',
#  'ambilobe',
#  'mys shmidta',
#  'malacky',
#  'yenagoa',
#  'ngunguru',
#  'bagdarin',
#  'birjand',
#  'tangshan',
#  'sur',
#  'saldanha',
#  'souillac',
#  'nuuk',
#  'bardsir',
#  'goderich',
#  'dvur kralove',
#  'quba',
#  'marapanim',
#  'urumqi',
#  'east london',
#  'bubaque',
#  'bengkulu',
#  'sao miguel do araguaia',
#  'portland',
#  'san isidro',
#  'tomigusuku',
#  'formosa do rio preto',
#  'faya',
#  'ponta do sol',
#  'vaitupu',
#  'pangkalanbuun',
#  'necochea',
#  'joshimath',
#  'carnarvon',
#  'kavieng',
#  'norman wells',
#  'namibe',
#  'kuah',
#  'innisfail',
#  'barra patuca',
#  'aklavik',
#  'grand river south east',
#  'imeni babushkina',
#  'vila',
#  'chernyshevskiy',
#  'chapais',
#  'bobo dioulasso',
#  'ocho rios',
#  'clarksburg',
#  'el alto',
#  'abu kamal',
#  'muravlenko',
#  'dera bugti',
#  'asha',
#  'victoria',
#  'port angeles',
#  'atlantic city',
#  'belaya gora',
#  'coquimbo',
#  'sovetskiy',
#  'kavaratti',
#  'alofi',
#  'bafq',
#  'ust-nera',
#  'olinda',
#  'sangin',
#  'takoradi',
#  'san clemente',
#  'hami',
#  'kysyl-syr',
#  'puerto del rosario',
#  'menomonie',
#  'saint-augustin',
#  'palabuhanratu',
#  'san cristobal',
#  'sitapur',
#  'sentyabrskiy',
#  'ilulissat',
#  'buqayq',
#  'geraldton',
#  'vestmannaeyjar',
#  'dukat',
#  'baft',
#  'progreso',
#  'caraballeda',
#  'samana',
#  'kaeo',
#  'laguna',
#  'vagur',
#  'alta floresta',
#  'coahuayana',
#  'kamenka',
#  'buy',
#  'shimoda',
#  'wuwei',
#  'oakham',
#  'tornio',
#  'orangeburg',
#  'hastings',
#  'athabasca',
#  'ciudad bolivar',
#  'antofagasta',
#  'calama',
#  'tecoanapa',
#  'kahului',
#  'qui nhon',
#  'pangai',
#  'cabedelo',
#  'weligama',
#  'nizhniy kuranakh',
#  'iskateley',
#  'limaong',
#  'kamenskoye',
#  'bulgan',
#  'quang ngai',
#  'doka',
#  'saint-francois',
#  'kharp',
#  'mahadday weyne',
#  'mananjary',
#  'port blair',
#  'mont-dore',
#  'santiago del estero',
#  'enumclaw',
#  'sobolevo',
#  'hailin',
#  'amnat charoen',
#  'codrington',
#  'nova olimpia',
#  'deputatskiy',
#  'umm lajj',
#  'salalah',
#  'tres arroyos',
#  'sexsmith',
#  'dingle',
#  'sarny',
#  'moose factory',
#  'saint-philippe',
#  'tessalit',
#  'amahai',
#  'prachuap khiri khan',
#  'khonuu',
#  'carutapera',
#  'khuzdar',
#  'allahganj',
#  'krupanj',
#  'kindia',
#  'meulaboh',
#  'kuala terengganu',
#  'sabha',
#  'tyshkivka',
#  'ursulo galvan',
#  'kegayli',
#  'koulamoutou',
#  'rameshki',
#  'port keats',
#  'marfino',
#  'provideniya',
#  'bogdanovich',
#  'waingapu',
#  'san juan',
#  'abonnema',
#  'college',
#  'leh',
#  'fairview',
#  'grindavik',
#  'zholymbet',
#  'freeport',
#  'kirakira',
#  'santa fe',
#  'broome',
#  'calvinia',
#  'solovetskiy',
#  'ghanzi',
#  'zhangjiakou',
#  'kununurra',
#  'nioro',
#  'foumban',
#  'north bend',
#  'paamiut',
#  'phan rang',
#  'san patricio',
#  'namie',
#  'louisbourg',
#  'skibbereen',
#  'palu',
#  'hirara',
#  'hurghada',
#  'beringovskiy',
#  'chicama',
#  'wad rawah',
#  'bajil',
#  'hilton head island',
#  'puerto rondon',
#  'novocherkassk',
#  'mackay',
#  'fairbanks',
#  'tiznit',
#  'yandoon',
#  'maldonado',
#  'kurumkan',
#  'inhambane',
#  'zaysan',
#  'fortuna',
#  'isangel',
#  'muros',
#  'birao',
#  'mergui',
#  'chunhuhub',
#  'tabulbah',
#  'agirish',
#  'huntsville',
#  'porto novo',
#  'maketu',
#  'mezhdurechensk',
#  'palaikastron',
#  'bad hofgastein',
#  'broken hill',
#  'yershov',
#  'mazatlan',
#  'humberto de campos',
#  'gambela',
#  'katangli',
#  'adrar',
#  'sorland',
#  'lappeenranta',
#  'machico',
#  'torres',
#  'arica',
#  'caravelas',
#  'sinnai',
#  'turukhansk',
#  'pozhva',
#  'itarema',
#  'shieli',
#  'minsk',
#  'jilib',
#  'yelan-kolenovskiy',
#  'concordia',
#  'yerofey pavlovich',
#  'fort nelson',
#  'batemans bay',
#  'donskoye',
#  'lar gerd',
#  'ankang',
#  'olafsvik',
#  'marshall',
#  'cocobeach',
#  'parana',
#  'terrace bay',
#  'yangjiang',
#  'vershino-darasunskiy',
#  'southbridge',
#  'novovarshavka',
#  'bandar-e anzali',
#  'cartagena',
#  'la ronge',
#  'los alamos',
#  'igarka',
#  'sogdiondon',
#  'solsvik',
#  'vao',
#  'strehaia',
#  'soderhamn',
#  'khvoynaya',
#  'richards bay',
#  'severodvinsk',
#  'poddorye',
#  'ovalle',
#  'taber',
#  'ust-omchug',
#  'callaway',
#  'znamenka',
#  'qaqortoq',
#  'umm durman',
#  'simi valley',
#  'kutum',
#  'daru',
#  'tikamgarh',
#  'shumikha',
#  'kautokeino',
#  'pochutla',
#  'cockburn town',
#  'waterfoot',
#  'naze',
#  'aviles',
#  'kloulklubed',
#  'banmo',
#  'zhetybay',
#  'vostok',
#  'wilmington',
#  'saint-gabriel',
#  'lubumbashi',
#  'karaul',
#  'sunndalsora',
#  'pemangkat',
#  'mayskiy',
#  'axim',
#  'baykit',
#  'anadyr',
#  'zhanatas',
#  'lichinga',
#  'athens',
#  'zhanaozen',
#  'sao joao da barra',
#  'vila franca do campo',
#  'mozarlandia',
#  'lazarev',
#  'kaohsiung',
#  'udachnyy',
#  'tignoan',
#  'sapele',
#  'mount gambier',
#  'padang',
#  'marsa matruh',
#  'belmonte',
#  'doctor pedro p. pena',
#  'melnikovo',
#  'aloleng',
#  'channel-port aux basques',
#  'tenenkou',
#  'le moule',
#  'sawtell',
#  'bani',
#  'oranjemund',
#  'peniche',
#  'aguimes',
#  'sao jose da coroa grande',
#  'jalu',
#  'dedougou',
#  'wulanhaote',
#  'coria',
#  'makinsk',
#  'kholmogory',
#  'ituni',
#  'ondorhaan',
#  'belyy yar',
#  'domoni',
#  'lasa',
#  'boyolangu',
#  'pitimbu',
#  'hobyo',
#  'arman',
#  'guangshui',
#  'el ocotito',
#  'bull savanna',
#  'lillooet',
#  'palana',
#  'ahipara',
#  'nome',
#  'cabo san lucas',
#  'montes altos',
#  'guerrero negro',
#  'tonj',
#  'nacala',
#  'tawkar',
#  'vila velha',
#  'kidal',
#  'rudbar',
#  'road town',
#  'esso',
#  'belle fourche',
#  'medicine hat',
#  'eidfjord',
#  'ust-kamchatsk',
#  'kotaparh']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Create base url
base_url = "http://api.openweathermap.org/data/2.5/weather?"

#Identify type of units
units = "imperial"

#create query url and get response from api
query_url = f"{base_url}appid={api_key}&units={units}&q="

#loop through cities
for city in cities:
   # record_count+=1
    try:
        response=requests.get(query_url + city).json()
        wind.append(response["wind"]["speed"])
        temp.append(response["main"]["temp"])
        lat.append(response["coord"]["lat"])
        lon.append(response["coord"]["lon"])
        humidity.append(response["main"]["humidity"])
        clouds.append(response["clouds"]["all"])
        #print(json.dumps(response, indent=4, sort_keys=True))
        #print(f"query record {record_count}, Response Status code:{response.status_code} for City :{city}")
        
    except:
        print("skipping.... City Not found")
        #response response.json()
        #pprint(response)
        
print(f'The temperature information received is: {temp}')
print(f'The latitude information received is: {lat}')
print(f'The humidity information received is: {humidity}')
print(f'The wind information received is: {wind}')
print(f'The clouds information received is: {clouds}')
# Out:
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
# skipping.... City Not found
, 92, 90, 90, 5, 40, 0, 20, 75, 0, 12, 1, 20, 90, 20, 90, 75, 20, 24, 40, 24, 8, 12, 75, 8, 24, 76, 0, 0, 0, 5, 80, 80, 75, 20, 0, 56, 1, 0, 8, 90, 68, 80, 0, 90, 75, 32, 100, 40, 90, 0, 8, 56, 0, 90, 56, 92, 0, 1, 75, 92, 90, 1, 88, 0, 68, 92, 75, 40, 76, 68, 90, 90, 92, 92, 1, 80, 88, 0, 64, 12, 0, 20, 90, 40, 92, 75, 0, 92, 90, 48, 1, 64, 20, 0, 0, 75, 40, 24, 90, 90, 8, 12, 75, 75, 40, 80, 24, 8, 80, 0, 0, 5, 75, 1, 40, 0, 0, 44, 1, 0, 48, 1, 56, 76, 20, 64, 76, 32, 0, 36, 90, 1, 40, 76, 76, 75, 0, 12, 0, 90, 0, 24, 20, 0, 0, 20, 76, 0, 24, 0, 56, 0, 88, 0, 92, 0, 48, 0, 24, 0, 44, 20, 0, 20, 1, 0, 75, 12, 40, 44, 80, 76, 0, 0, 32, 5, 68, 20, 0, 20, 92, 0, 80, 90, 20, 75, 75, 24, 0, 0, 92, 75, 1, 0, 0, 92, 20, 0, 0, 8, 40, 24, 12, 75, 80, 80, 0, 40, 0, 75, 0, 0, 20, 0, 68, 0, 20, 20, 12, 44, 90, 56, 32, 8, 76, 92, 75, 0, 92, 0, 1, 0, 48, 0, 75, 0, 5, 75, 20, 0, 32, 24, 76, 40, 20, 0, 0, 0, 12, 12, 40, 90, 76, 1, 44, 64, 0, 0, 32, 0, 0, 0, 24, 75, 0, 44, 40, 75, 8, 12, 0, 68, 0, 0, 0, 0, 24, 75, 0, 12, 90, 24, 44, 0, 90, 0, 36, 68, 20, 20, 75, 32, 40, 20, 68, 75, 32, 80, 1, 0, 24, 0, 0, 0, 64, 90, 64, 8, 75, 75, 24, 75, 32, 75, 0, 76, 1, 0, 20, 5, 75, 44, 20, 0, 92, 80, 75, 75, 75, 0, 100, 88, 1, 0, 0, 20, 0, 75, 0, 40, 88, 20, 12, 0, 88, 0, 20, 44, 0, 76, 20, 68, 88, 36, 0, 75, 0, 88, 0, 0, 75, 76, 0, 44, 1, 75, 0, 0, 80, 24, 1, 76, 12, 88, 20, 1, 64, 0, 0, 32, 56, 36, 0, 12, 0, 75, 24, 1, 88, 88, 90, 0, 0, 0, 20, 8, 5, 100, 92, 20, 40, 75, 0, 40, 90, 80, 8, 8, 36, 32, 32, 24, 1, 0, 76, 75, 48, 24, 20, 80, 20, 68, 40, 20, 0, 92, 64, 0, 0, 8, 75, 0, 0, 0, 75, 20, 76, 0, 0,  ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#create dictionary and dataframe with city as the index
data = {'Cities':[city],
        "Latitude":[lat], 
        "Temperature":[temp], 
        "Humidity":[humidity], 
        "Wind Speed": [wind], 
        "Clouds": [clouds]}
df = pd.DataFrame(data)
df.head()
# Out:
#      Cities                                           Latitude  \
# 0  kotaparh  [65.95, -34.42, 43.36, -33.93, -54.81, 28.58, ...
#
#                                          Temperature  \
# 0  [18.54, 66.33, 28.4, 65.35, 42.8, 51.8, 12.54,...
#
#                                             Humidity  \
# 0  [82, 83, 100, 88, 75, 93, 78, 90, 84, 88, 54, ...
#
#                                           Wind Speed  \
# 0  [7.74, 7, 2.24, 5.82, 21.92, 4.7, 15.66, 15.01...
#
#                                               Clouds
# 0  [76, 0, 75, 0, 20, 0, 36, 68, 8, 0, 76, 76, 48...

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Create scatter plot
plt.scatter(df["Latitude"], df["Temperature"], marker="o")

# Incorporate the other graph properties
plt.title("Latitude vs. Temperature")
plt.ylabel("Temperature (Farenheit)")
plt.xlabel("Latitude")
plt.grid(True)

#Show graph
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-2f57e63421f2> in <module>
#       1 #Create scatter plot
# ----> 2 plt.scatter(df["Latitude"], df["Temperature"], marker="o")
#       3
#       4 # Incorporate the other graph properties
#       5 plt.title("Latitude vs. Temperature")
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, data, **kwargs)
#    2862         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2863         verts=verts, edgecolors=edgecolors, **({"data": data} if data
# -> 2864         is not None else {}), **kwargs)
#    2865     sci(__ret)
#    2866     return __ret
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4295                 offsets=offsets,
#    4296                 transOffset=kwargs.pop('transform', self.transData),
# -> 4297                 alpha=alpha
#    4298                 )
#    4299         collection.set_transform(mtransforms.IdentityTransform())
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\collections.py in __init__(self, paths, sizes, **kwargs)
#     897         """
#     898
# --> 899         Collection.__init__(self, **kwargs)
#     900         self.set_paths(paths)
#     901         self.set_sizes(sizes)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\collections.py in __init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, offset_position, zorder, **kwargs)
#     153         self._uniform_offsets = None
#     154         if offsets is not None:
# --> 155             offsets = np.asanyarray(offsets, float)
#     156             # Broadcast (2,) -> (1, 2) but nothing else.
#     157             if offsets.shape == (2,):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\numpy\core\numeric.py in asanyarray(a, dtype, order)
#     551
#     552     """
# --> 553     return array(a, dtype, copy=False, order=order, subok=True)
#     554
#     555
#
# ValueError: setting an array element with a sequence.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#Create scatter plot
plt.scatter(df["Latitude"], df["Humidity"])

# Incorporate the other graph properties
plt.title("Latitude vs. Humidity")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

#Show graph
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-4a7502b02ade> in <module>
#       1 #Create scatter plot
# ----> 2 plt.scatter(df["Latitude"], df["Humidity"])
#       3
#       4 # Incorporate the other graph properties
#       5 plt.title("Latitude vs. Humidity")
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, data, **kwargs)
#    2862         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2863         verts=verts, edgecolors=edgecolors, **({"data": data} if data
# -> 2864         is not None else {}), **kwargs)
#    2865     sci(__ret)
#    2866     return __ret
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4295                 offsets=offsets,
#    4296                 transOffset=kwargs.pop('transform', self.transData),
# -> 4297                 alpha=alpha
#    4298                 )
#    4299         collection.set_transform(mtransforms.IdentityTransform())
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\collections.py in __init__(self, paths, sizes, **kwargs)
#     897         """
#     898
# --> 899         Collection.__init__(self, **kwargs)
#     900         self.set_paths(paths)
#     901         self.set_sizes(sizes)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\collections.py in __init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, offset_position, zorder, **kwargs)
#     153         self._uniform_offsets = None
#     154         if offsets is not None:
# --> 155             offsets = np.asanyarray(offsets, float)
#     156             # Broadcast (2,) -> (1, 2) but nothing else.
#     157             if offsets.shape == (2,):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\numpy\core\numeric.py in asanyarray(a, dtype, order)
#     551
#     552     """
# --> 553     return array(a, dtype, copy=False, order=order, subok=True)
#     554
#     555
#
# ValueError: setting an array element with a sequence.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#Create scatter plot
plt.scatter(df["Latitude"], df["Clouds"])

# Incorporate the other graph properties
plt.title("Latitude vs. Clouds")
plt.ylabel("Clouds")
plt.xlabel("Latitude")
plt.grid(True)

#Show graph
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-648fb39a9624> in <module>
#       1 #Create scatter plot
# ----> 2 plt.scatter(df["Latitude"], df["Clouds"])
#       3
#       4 # Incorporate the other graph properties
#       5 plt.title("Latitude vs. Clouds")
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, data, **kwargs)
#    2862         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2863         verts=verts, edgecolors=edgecolors, **({"data": data} if data
# -> 2864         is not None else {}), **kwargs)
#    2865     sci(__ret)
#    2866     return __ret
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4295                 offsets=offsets,
#    4296                 transOffset=kwargs.pop('transform', self.transData),
# -> 4297                 alpha=alpha
#    4298                 )
#    4299         collection.set_transform(mtransforms.IdentityTransform())
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\collections.py in __init__(self, paths, sizes, **kwargs)
#     897         """
#     898
# --> 899         Collection.__init__(self, **kwargs)
#     900         self.set_paths(paths)
#     901         self.set_sizes(sizes)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\collections.py in __init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, offset_position, zorder, **kwargs)
#     153         self._uniform_offsets = None
#     154         if offsets is not None:
# --> 155             offsets = np.asanyarray(offsets, float)
#     156             # Broadcast (2,) -> (1, 2) but nothing else.
#     157             if offsets.shape == (2,):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\numpy\core\numeric.py in asanyarray(a, dtype, order)
#     551
#     552     """
# --> 553     return array(a, dtype, copy=False, order=order, subok=True)
#     554
#     555
#
# ValueError: setting an array element with a sequence.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#Create scatter plot
plt.scatter(df["Latitude"], df["Wind Speed"])

# Incorporate the other graph properties
plt.title("Latitude vs. Wind Speed")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

#Show graph
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-7fb7259cb7e5> in <module>
#       1 #Create scatter plot
# ----> 2 plt.scatter(df["Latitude"], df["Wind Speed"])
#       3
#       4 # Incorporate the other graph properties
#       5 plt.title("Latitude vs. Wind Speed")
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, data, **kwargs)
#    2862         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2863         verts=verts, edgecolors=edgecolors, **({"data": data} if data
# -> 2864         is not None else {}), **kwargs)
#    2865     sci(__ret)
#    2866     return __ret
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4295                 offsets=offsets,
#    4296                 transOffset=kwargs.pop('transform', self.transData),
# -> 4297                 alpha=alpha
#    4298                 )
#    4299         collection.set_transform(mtransforms.IdentityTransform())
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\collections.py in __init__(self, paths, sizes, **kwargs)
#     897         """
#     898
# --> 899         Collection.__init__(self, **kwargs)
#     900         self.set_paths(paths)
#     901         self.set_sizes(sizes)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\collections.py in __init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, offset_position, zorder, **kwargs)
#     153         self._uniform_offsets = None
#     154         if offsets is not None:
# --> 155             offsets = np.asanyarray(offsets, float)
#     156             # Broadcast (2,) -> (1, 2) but nothing else.
#     157             if offsets.shape == (2,):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\numpy\core\numeric.py in asanyarray(a, dtype, order)
#     551
#     552     """
# --> 553     return array(a, dtype, copy=False, order=order, subok=True)
#     554
#     555
#
# ValueError: setting an array element with a sequence.
